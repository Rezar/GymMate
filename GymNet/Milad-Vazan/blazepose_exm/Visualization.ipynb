# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
def connectpoints_2d(x,y,p1,p2):
    x1, x2 = x[p1], x[p2]
    y1, y2 = y[p1], y[p2]
    plt.plot([x1,x2],[y1,y2],'k-')

# %%
dataset = pd.read_csv('F:/blazepose_3D.csv')

# %%
len(eval(dataset.xX_left_shoulder[0]))
# Out:
# 217

# %%
len(eval(dataset.yY_left_shoulder[0]))
# Out:
# 217

# %%
len(eval(dataset.zZ_left_shoulder[0]))
# Out:
# 217

# %%
len(eval(dataset.xX_left_shoulder[0]))==len(eval(dataset.yY_left_shoulder[0]))==len(eval(dataset.zZ_left_shoulder[0]))
# Out:
# True

# %%
i=25
m=0 #show number frame
print (dataset.name[i])
for j in range (len (eval(dataset.xX_left_shoulder[i]))):
    kx1 =eval(dataset.xX_left_shoulder[i])
    ky1=eval(dataset.yY_left_shoulder[i])
    kz1=eval(dataset.zZ_left_shoulder[i])
    s1=kx1[j]
    t1=1-ky1[j]
    z1=kz1[j]

    kx1 =eval(dataset.xX_right_shoulder[i])
    ky1=eval(dataset.yY_right_shoulder[i])
    kz1=eval(dataset.zZ_right_shoulder[i])
    s2=kx1[j]
    t2=1-ky1[j]
    z2=kz1[j]

    kx1 =eval(dataset.xX_left_wrist[i])
    ky1=eval(dataset.yY_left_wrist[i])
    kz1=eval(dataset.zZ_left_wrist[i])
    s3=kx1[j]
    t3=1-ky1[j]
    z3=kz1[j]


    kx1 =eval(dataset.xX_right_wrist[i])
    ky1=eval(dataset.yY_right_wrist[i])
    kz1=eval(dataset.zZ_right_wrist[i])
    s4=kx1[j]
    t4=1-ky1[j]
    z4=kz1[j]


    kx1 =eval(dataset.xX_left_elbow[i])
    ky1=eval(dataset.yY_left_elbow[i])
    kz1=eval(dataset.zZ_left_elbow[i])
    s5=kx1[j]
    t5=1-ky1[j]
    z5=kz1[j]


    kx1 =eval(dataset.xX_right_elbow[i])
    ky1=eval(dataset.yY_right_elbow[i])
    kz1=eval(dataset.zZ_right_elbow[i])
    s6=kx1[j]
    t6=1-ky1[j]
    z6=kz1[j]


    kx1 =eval(dataset.xX_left_hip[i])
    ky1=eval(dataset.yY_left_hip[i])
    kz1=eval(dataset.zZ_left_hip[i])
    s7=kx1[j]
    t7=1-ky1[j]
    z7=kz1[j]


    kx1 =eval(dataset.xX_right_hip[i])
    ky1=eval(dataset.yY_right_hip[i])
    kz1=eval(dataset.zZ_right_hip[i])
    s8=kx1[j]
    t8=1-ky1[j]
    z8=kz1[j]


    kx1 =eval(dataset.xX_left_knee[i])
    ky1=eval(dataset.yY_left_knee[i])
    kz1=eval(dataset.zZ_left_knee[i])
    s9=kx1[j]
    t9=1-ky1[j]
    z9=kz1[j]


    kx1 =eval(dataset.xX_right_knee[i])
    ky1=eval(dataset.yY_right_knee[i])
    kz1=eval(dataset.zZ_right_knee[i])
    s10=kx1[j]
    t10=1-ky1[j]
    z10=kz1[j]


    kx1 =eval(dataset.xX_left_ankle[i])
    ky1=eval(dataset.yY_left_ankle[i])
    kz1=eval(dataset.zZ_left_ankle[i])
    s11=kx1[j]
    t11=1-ky1[j]
    z11=kz1[j]


    kx1 =eval(dataset.xX_right_ankle[i])
    ky1=eval(dataset.yY_right_ankle[i])
    kz1=eval(dataset.zZ_right_ankle[i])
    s12=kx1[j]
    t12=1-ky1[j]
    z12=kz1[j]


    X=[]
    Y=[]
    z=[]
    X.append(s1)
    X.append(s2)
    X.append(s3)
    X.append(s4)
    X.append(s5)
    X.append(s6)
    X.append(s7)
    X.append(s8)
    X.append(s9)
    X.append(s10)
    X.append(s11)
    X.append(s12)
    Y.append(t1)
    Y.append(t2)
    Y.append(t3)
    Y.append(t4)
    Y.append(t5)
    Y.append(t6)
    Y.append(t7)
    Y.append(t8)
    Y.append(t9)
    Y.append(t10)
    Y.append(t11)
    Y.append(t12)
    z.append(z1)
    z.append(z2)
    z.append(z3)
    z.append(z4)
    z.append(z5)
    z.append(z6)
    z.append(z7)
    z.append(z8)
    z.append(z9)
    z.append(z10)
    z.append(z11)
    z.append(z12)
    plt.plot(X,Y, 'ro')

    connectpoints_2d(X,Y,0,1)
    connectpoints_2d(X,Y,1,3)
    connectpoints_2d(X,Y,0,2)
    connectpoints_2d(X,Y,3,5)
    connectpoints_2d(X,Y,2,4)
    connectpoints_2d(X,Y,1,7)
    connectpoints_2d(X,Y,0,6)
    connectpoints_2d(X,Y,6,7)
    connectpoints_2d(X,Y,7,9)
    connectpoints_2d(X,Y,6,8)
    connectpoints_2d(X,Y,9,11)
    connectpoints_2d(X,Y,8,10)

    plt.axis('equal')
    plt.title(f"frame:{m}")
    m+=1    
    plt.show()
# Out:
# hummer curls
