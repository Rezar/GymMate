# %%
import cv2
import time
import os
def video_to_frames(input_loc, output_loc):
    try:
        os.mkdir(output_loc)
    except OSError:
        pass
    time_start = time.time()
    cap = cv2.VideoCapture(input_loc)
    video_length = int(cap.get(cv2.CAP_PROP_FRAME_COUNT)) - 1
    print ("Number of frames: ", video_length)
    count = 0
    print ("Converting video..\n")
    while cap.isOpened():
        # Extract the frame
        ret, frame = cap.read()
        if not ret:
            continue
        # Write the results back to output location.
        cv2.imwrite(output_loc + "/%#05d.jpg" % (count+1), frame)
        count = count + 1
        # If there are no more frames left
        if (count > (video_length-1)):
            # Log the time again
            time_end = time.time()
            # Release the feed
            cap.release()
            # Print stats
            print ("Done extracting frames.\n%d frames extracted" % count)
            print ("It took %d seconds forconversion." % (time_end-time_start))
            break

# %%
import pandas as pd
dataset = pd.read_csv('/content/drive/MyDrive/vf_frame/folder.csv')
for index, row in dataset.iterrows():
    input_loc = row["folderadd"]
    output_loc = row["folder"]
    video_to_frames(input_loc, output_loc)
# Out:
# Number of frames:  233
# Converting video..
#
# Done extracting frames.
# 233 frames extracted
# It took 8 seconds forconversion.
# Number of frames:  285
# Converting video..
#
# Done extracting frames.
# 285 frames extracted
# It took 8 seconds forconversion.
# Number of frames:  128
# Converting video..
#
# Done extracting frames.
# 128 frames extracted
# It took 3 seconds forconversion.
# Number of frames:  156
# Converting video..
#
# Done extracting frames.
# 156 frames extracted
# It took 4 seconds forconversion.
# Number of frames:  173
# Converting video..
#
# Done extracting frames.
# 173 frames extracted
# It took 5 seconds forconversion.
# Number of frames:  165
# Converting video..
#
# Done extracting frames.
# 165 frames extracted
# It took 4 seconds forconversion.
# Number of frames:  242
# Converting video..
#
# Done extracting frames.
# 242 frames extracted
# It took 6 seconds forconversion.
# Number of frames:  162
# Converting video..
#
# Done extracting frames.
# 162 frames extracted
# It took 4 seconds forconversion.
# Number of frames:  171
# Converting video..
#
# Done extracting frames.
# 171 frames extracted
# It took 4 seconds forconversion.
# Number of frames:  139
# Converting video..
#
# Done extracting frames.
# 139 frames extracted
# It took 3 seconds forconversion.
# Number of frames:  101
# Converting video..
#
# Done extracting frames.
# 101 frames extracted
# It took 2 seconds forconversion.
# Number of frames:  115
# Converting video..
#
# Done extracting frames.
# 115 frames extracted
# It took 3 seconds forconversion.
# Number of frames:  242
# Converting video..
#
# Done extracting frames.
# 242 frames extracted
# It took 7 seconds forconversion.
# Number of frames:  292
# Converting video..
#
# Done extracting frames.
# 292 frames extracted
# It took 8 seconds forconversion.
# Number of frames:  255
# Converting video..
#
# Done extracting frames.
# 255 frames extracted
# It took 10 seconds forconversion.
# Number of frames:  232
# Converting video..
#
# Done extracting frames.
# 232 frames extracted
# It took 6 seconds forconversion.
# Number of frames:  211
# Converting video..
#
# Done extracting frames.
# 211 frames extracted
# It took 6 seconds forconversion.
# Number of frames:  189
# Converting video..
#
# Done extracting frames.
# 189 frames extracted
# It took 5 seconds forconversion.
# Number of frames:  206
# Converting video..
#
# Done extracting frames.
# 206 frames extracted
# It took 5 seconds forconversion.
# Number of frames:  194
# Converting video..
#
# Done extracting frames.
# 194 frames extracted
# It took 6 seconds forconversion.
# Number of frames:  181
# Converting video..
#
# Done extracting frames.
# 181 frames extracted
# It took 4 seconds forconversion.
# Number of frames:  248
# Converting video..
#
# Done extracting frames.
# 248 frames extracted
# It took 7 seconds forconversion.
# Number of frames:  283
# Converting video..
#
# Done extracting frames.
# 283 frames extracted
# It took 7 seconds forconversion.
# Number of frames:  241
# Converting video..
#
# Done extracting frames.
# 241 frames extracted
# It took 6 seconds forconversion.
# Number of frames:  171
# Converting video..
#
# Done extracting frames.
# 171 frames extracted
# It took 5 seconds forconversion.
# Number of frames:  268
# Converting video..
#
# Done extracting frames.
# 268 frames extracted
# It took 7 seconds forconversion.
# Number of frames:  152
# Converting video..
#
# Done extracting frames.
# 152 frames extracted
# It took 4 seconds forconversion.
# Number of frames:  240
# Converting video..
#
# Done extracting frames.
# 240 frames extracted
# It took 6 seconds forconversion.
# Number of frames:  257
# Converting video..
#
# Done extracting frames.
# 257 frames extracted
# It took 8 seconds forconversion.
# Number of frames:  247
# Converting video..
#
# Done extracting frames.
# 247 frames extracted
# It took 8 seconds forconversion.
# Number of frames:  104
# Converting video..
#
# Done extracting frames.
# 104 frames extracted
# It took 3 seconds forconversion.
# Number of frames:  142
# Converting video..
#
# Done extracting frames.
# 142 frames extracted
# It took 4 seconds forconversion.
# Number of frames:  100
# Converting video..
#
# Done extracting frames.
# 100 frames extracted
# It took 3 seconds forconversion.
# Number of frames:  215
# Converting video..
#
# Done extracting frames.
# 215 frames extracted
# It took 6 seconds forconversion.
# Number of frames:  269
# Converting video..
#
# Done extracting frames.
# 269 frames extracted
# It took 7 seconds forconversion.
# Number of frames:  353
# Converting video..
#
# Done extracting frames.
# 353 frames extracted
# It took 9 seconds forconversion.
# Number of frames:  251
# Converting video..
#
# Done extracting frames.
# 251 frames extracted
# It took 6 seconds forconversion.
# Number of frames:  181
# Converting video..
#
# Done extracting frames.
# 181 frames extracted
# It took 6 seconds forconversion.
# Number of frames:  228
# Converting video..
#
# Done extracting frames.
# 228 frames extracted
# It took 7 seconds forconversion.
# Number of frames:  311
# Converting video..
#
# Done extracting frames.
# 311 frames extracted
# It took 8 seconds forconversion.
# Number of frames:  299
# Converting video..
#
# Done extracting frames.
# 299 frames extracted
# It took 8 seconds forconversion.
# Number of frames:  242
# Converting video..
#
# Done extracting frames.
# 242 frames extracted
# It took 6 seconds forconversion.
# Number of frames:  270
# Converting video..
#
# Done extracting frames.
# 270 frames extracted
# It took 7 seconds forconversion.
# Number of frames:  317
# Converting video..
#
# Done extracting frames.
# 317 frames extracted
# It took 9 seconds forconversion.
# Number of frames:  186
# Converting video..
#
# Done extracting frames.
# 186 frames extracted
# It took 5 seconds forconversion.
# Number of frames:  272
# Converting video..
